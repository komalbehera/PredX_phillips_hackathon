# %%
import pandas as pd
import yaml
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import joblib

#visualizatin
import seaborn as sn
import matplotlib.pyplot as plt

#model building
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
class PredictDisease:
    
    def __init__(self,model_name=None):
        #loading the yaml config and initializing the model:
        path=r"C:\Users\dell\Desktop\projects\Phillps_hac\config.yaml"
        try: 
            with open (path, 'r') as file:
                self.config = yaml.safe_load(file)
        except Exception as e:
            print('Error reading the config file')
    
        #defining the parameters from config file:
        self.verbose=self.config['verbose']
    
        #loading train parameters :
        self.train_feat,self.train_labels, self.train_df=self._loading_train()
    
        #loading test parameters :
        self.test_feat,self.test_labels, self.test_df=self._loading_test()
        
        self.model_name=model_name
        
        #path for saving the model
        self.model_save_path = self.config['model_save_path']
        
        #saving data visualization 
       # self._feature_correlation(data_frame=self.train_df, show_fig=False)
        
    #function to load train dataset:
    def _loading_train(self):
        df_train=pd.read_csv(self.config['dataset']['training_data_path'])
        #the last column is not needed and the 2nd last column gives us the y-labels 
        columns=df_train.columns[:-2]
        
        #the training feature vectors
        train_feat=df_train[columns]
        
        #the y labels for train set
        train_labels=df_train['prognosis']
        
        if self.verbose:
            print("Length of Training Data: ", df_train.shape)
            print("Training Features: ", train_feat.shape)
            print("Training Labels: ", train_labels.shape)
            
        return train_feat, train_labels, df_train
    
    #function to load the test data 
    def _loading_test(self):
        df_test=pd.read_csv(self.config['dataset']['test_data_path'])
        #the last column is not needed and the 2nd last column gives us the y-labels 
        columns=df_test.columns[:-1]
        
        #the training feature vectors
        test_feat=df_test[columns]
        
        #the y labels for train set
        test_labels=df_test['prognosis']
        
        if self.verbose:
            print("Length of Training Data: ", df_test.shape)
            print("Training Features: ", test_feat.shape)
            print("Training Labels: ", test_labels.shape)
            
        return test_feat, test_labels, df_test
    
    #model selection 
    def select_model(self):
        if self.model_name == 'mnb':
            self.clf = MultinomialNB()
        elif self.model_name == 'decision_tree':
            self.clf = DecisionTreeClassifier(criterion=self.config['model']['decision_tree']['criterion'])
        elif self.model_name == 'random_forest':
            self.clf = RandomForestClassifier(n_estimators=self.config['model']['random_forest']['n_estimators'])
        elif self.model_name == 'gradient_boost':
            self.clf = GradientBoostingClassifier(n_estimators=self.config['model']['gradient_boost']['n_estimators'],
                                                  criterion=self.config['model']['gradient_boost']['criterion'])
        return self.clf
    
    # Dataset Train Validation Split
    def _train_val_split(self):
        X_train, X_val, y_train, y_val = train_test_split(self.train_feat, self.train_labels,
                                                          test_size=self.config['dataset']['validation_size'],
                                                          random_state=self.config['random_state'])

        if self.verbose:
            print("Number of Training Features: {0}\tNumber of Training Labels: {1}".format(len(X_train), len(y_train)))
            print("Number of Validation Features: {0}\tNumber of Validation Labels: {1}".format(len(X_val), len(y_val)))
            
        return X_train, y_train, X_val, y_val
    
    # ML Model
    def train_model(self):
        # Get the Data
        X_train, y_train, X_val, y_val = self._train_val_split()
        classifier = self.select_model()
        # Training the Model
        classifier = classifier.fit(X_train, y_train)
        # Trained Model Evaluation on Validation Dataset
        confidence = classifier.score(X_val, y_val)
        # Validation Data Prediction
        y_pred = classifier.predict(X_val)
        # Model Validation Accuracy
        accuracy = accuracy_score(y_val, y_pred)
        # Model Confusion Matrix
        conf_mat = confusion_matrix(y_val, y_pred)
        # Model Classification Report
        clf_report = classification_report(y_val, y_pred)
        # Model Cross Validation Score
        score = cross_val_score(classifier, X_val, y_val, cv=3)
        
        
        if self.verbose:
            print('\nTraining Accuracy: ', confidence)
            print('\nValidation Prediction: ', y_pred)
            print('\nValidation Accuracy: ', accuracy)
            print('\nValidation Confusion Matrix: \n', conf_mat)
            print('\nCross Validation Score: \n', score)
            print('\nClassification Report: \n', clf_report)
            
        # Save Trained Model
        filename=r"C:\Users\dell\Desktop\projects\Phillps_hac\saved_model"+str(self.model_name)
        joblib.dump(classifier, filename + ".joblib")
        
    def _feature_correlation(self, data_frame=None, show_fig=False):
        # Get Feature Correlation
        corr = data_frame.corr()
        fig, ax = plt.subplots()
        fig.set_size_inches(14, 14)
        sn.heatmap(corr, square=True, annot=False, cmap="YlGnBu")
        plt.title("Feature Correlation")
        plt.tight_layout()
        #plt.show()
        plt.savefig(r'C:\Users\dell\Desktop\projects\Phillps_hac\feature_correlation.png')
    
    # Function to Make Predictions on Test Data
    def make_prediction(self, saved_model_name=None, test_data=None):
        try:
            # Load Trained Model
            filename=r"C:\Users\dell\Desktop\projects\Phillps_hac\saved_model"+str(self.model_name)
            clf = joblib.load(filename +  ".joblib")
        except Exception as e:
            print("Model not found...")

        if test_data is not None:
            result = clf.predict(test_data)
            return result
        else:
            result = clf.predict(self.test_feat)
            
        accuracy = accuracy_score(self.test_labels, result)
        clf_report = classification_report(self.test_labels, result)
        return accuracy,clf_report

# %%
if __name__=='__main__':
    print("Available models are as follows :")
    print("Press 1 for Decision Trees")
    print("Press 2 for Multinomial NB")
    print("Press 3 for RandomForestClassifier")
    print("Press 4 for GradientBoostingClassifier")
    x=int(input())
    if x==1:
        _model_name="decision_tree"
    elif x==2:
        _model_name="mnb"
    elif x==3:
        _model_name="random_forest"
    elif x==4:
        _model_name="gradient_boost"
    else :
        print("please choose valid number between 1 to 4")
    
    
    disease_model=PredictDisease(model_name=_model_name)
    
    #train the model
    disease_model.train_model()
    
    #make predictions on test data:
    test_acc,clf_report=disease_model.make_prediction(saved_model_name=_model_name)
# Out:
# Available models are as follows :
# Press 1 for Decision Trees
# Press 2 for Multinomial NB
# Press 3 for RandomForestClassifier
# Press 4 for GradientBoostingClassifier
# 1
# Length of Training Data:  (4920, 134)
# Training Features:  (4920, 132)
# Training Labels:  (4920,)
# Length of Training Data:  (42, 133)
# Training Features:  (42, 132)
# Training Labels:  (42,)
# Number of Training Features: 3936	Number of Training Labels: 3936
# Number of Validation Features: 984	Number of Validation Labels: 984
#
# Training Accuracy:  1.0
#
# Validation Prediction:  ['Migraine' 'Common Cold' 'Hepatitis B' 'Gastroenteritis'
#  'Alcoholic hepatitis' 'Heart attack' 'Hepatitis E' 'Hypothyroidism'
#  'Malaria' 'Gastroenteritis' '(vertigo) Paroymsal  Positional Vertigo'
#  'Osteoarthristis' 'Impetigo' 'Hepatitis D' 'Bronchial Asthma' 'Impetigo'
#  'Alcoholic hepatitis' 'Alcoholic hepatitis'
#  'Paralysis (brain hemorrhage)' 'Typhoid' 'Bronchial Asthma'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Malaria' 'Hepatitis B'
#  'Typhoid' 'AIDS' 'Hyperthyroidism' 'Hypoglycemia' 'Varicose veins'
#  'Chicken pox' 'Hepatitis E' 'Malaria' 'Arthritis' 'Acne' 'Varicose veins'
#  'Psoriasis' 'Hepatitis E' 'hepatitis A' 'Hepatitis D' 'Impetigo'
#  'Drug Reaction' 'Impetigo' 'Cervical spondylosis' 'Typhoid' 'Psoriasis'
#  'Hypoglycemia' 'Diabetes ' 'AIDS' 'Hypertension ' 'Bronchial Asthma'
#  'Common Cold' 'Cervical spondylosis' 'Chicken pox' 'Hepatitis C'
#  'Fungal infection' 'Fungal infection' 'Acne' 'Acne' 'Arthritis'
#  'Hepatitis D' 'Varicose veins' 'GERD' 'Hepatitis E' 'Bronchial Asthma'
#  'Psoriasis' 'Tuberculosis' 'Bronchial Asthma' 'Chicken pox'
#  'Fungal infection' 'Dengue' 'Drug Reaction' 'Peptic ulcer diseae'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Chicken pox' 'Chicken pox'
#  'Fungal infection' 'Chronic cholestasis' 'Drug Reaction'
#  'Cervical spondylosis' 'Diabetes ' 'Paralysis (brain hemorrhage)'
#  'Hypothyroidism' 'Allergy' 'Paralysis (brain hemorrhage)' 'Drug Reaction'
#  'Acne' 'Typhoid' 'Heart attack' 'Hepatitis D' 'GERD' 'Pneumonia'
#  'Common Cold' 'Paralysis (brain hemorrhage)' 'Allergy' 'Hepatitis C'
#  'Jaundice' 'Urinary tract infection' 'Peptic ulcer diseae' 'Pneumonia'
#  'Hepatitis E' 'Paralysis (brain hemorrhage)' 'Hypertension ' 'Acne'
#  'Dimorphic hemmorhoids(piles)' 'Paralysis (brain hemorrhage)'
#  'Hypothyroidism' 'Allergy' 'Alcoholic hepatitis' 'Hepatitis D'
#  'Diabetes ' 'Impetigo' 'Chicken pox' 'hepatitis A' 'Fungal infection'
#  'Urinary tract infection' 'Osteoarthristis' 'AIDS' 'Migraine'
#  'Heart attack' 'Peptic ulcer diseae' 'Bronchial Asthma' 'Impetigo'
#  'Heart attack' 'Chronic cholestasis' 'Peptic ulcer diseae' 'Arthritis'
#  'Jaundice' 'Hepatitis B' 'Chronic cholestasis' 'Hypothyroidism' 'Dengue'
#  'Hypoglycemia' 'Osteoarthristis' 'Hepatitis E' 'GERD' 'Diabetes '
#  'Diabetes ' 'Bronchial Asthma' 'Acne' 'Impetigo' 'Bronchial Asthma'
#  'Heart attack' 'Bronchial Asthma' 'Common Cold' 'Hepatitis D' 'Acne'
#  'Diabetes ' 'Allergy' 'Paralysis (brain hemorrhage)' 'Hepatitis B'
#  '(vertigo) Paroymsal  Positional Vertigo' 'GERD' 'Osteoarthristis'
#  'Impetigo' 'Acne' 'Hepatitis D' 'Arthritis' 'Arthritis' 'Pneumonia'
#  'Chicken pox' 'Typhoid' 'Gastroenteritis' 'AIDS' 'Psoriasis'
#  'Common Cold' 'Malaria' 'Tuberculosis' 'Hepatitis D' 'Hepatitis B'
#  'Dimorphic hemmorhoids(piles)' 'Arthritis' 'Impetigo'
#  'Cervical spondylosis' 'AIDS' 'Dengue' 'Heart attack' 'Tuberculosis'
#  'Common Cold' 'Hepatitis C' '(vertigo) Paroymsal  Positional Vertigo'
#  'Common Cold' 'Peptic ulcer diseae' 'Typhoid' 'Varicose veins'
#  'Hepatitis B' 'Alcoholic hepatitis' 'Drug Reaction' 'Hypothyroidism'
#  'Jaundice' 'Peptic ulcer diseae' 'Allergy' 'hepatitis A'
#  'Urinary tract infection' 'Cervical spondylosis' 'GERD' 'Dengue'
#  'Peptic ulcer diseae' 'AIDS' 'Bronchial Asthma' 'Varicose veins'
#  'Varicose veins' 'Hepatitis B' 'Malaria' 'Heart attack' 'hepatitis A'
#  'Acne' 'Hypoglycemia' 'hepatitis A' 'Tuberculosis' 'Osteoarthristis'
#  'Fungal infection' 'Diabetes ' 'GERD' 'Impetigo' 'Arthritis'
#  'Gastroenteritis' 'Pneumonia' 'Arthritis' 'Hypertension '
#  'Urinary tract infection' 'hepatitis A' 'Malaria' 'Typhoid'
#  'Urinary tract infection' 'Alcoholic hepatitis' 'Peptic ulcer diseae'
#  'Impetigo' 'Hepatitis E' 'Dengue' 'Paralysis (brain hemorrhage)'
#  'Gastroenteritis' 'hepatitis A' 'Heart attack' 'hepatitis A'
#  'Osteoarthristis' 'Psoriasis' 'Acne' 'Tuberculosis' 'Hypoglycemia'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Paralysis (brain hemorrhage)'
#  'Varicose veins' 'Acne' 'Cervical spondylosis' 'Alcoholic hepatitis'
#  'GERD' '(vertigo) Paroymsal  Positional Vertigo' 'Chronic cholestasis'
#  'Hyperthyroidism' '(vertigo) Paroymsal  Positional Vertigo'
#  'Cervical spondylosis' 'Bronchial Asthma' 'Drug Reaction'
#  'Gastroenteritis' 'Dimorphic hemmorhoids(piles)' 'GERD' 'Heart attack'
#  'Cervical spondylosis' 'Jaundice' 'GERD' 'Varicose veins' 'Tuberculosis'
#  'Hypothyroidism' 'Gastroenteritis' 'Impetigo' 'Typhoid'
#  'Cervical spondylosis' 'Chicken pox' 'Allergy' 'Alcoholic hepatitis'
#  'Dengue' 'Impetigo' 'Tuberculosis' 'Typhoid' 'Pneumonia'
#  'Alcoholic hepatitis' 'Allergy' 'Gastroenteritis' 'Pneumonia'
#  'Hyperthyroidism' 'Urinary tract infection' 'Hypothyroidism'
#  'Paralysis (brain hemorrhage)' 'Hepatitis B' 'Peptic ulcer diseae'
#  'Varicose veins' 'Malaria' 'Chicken pox' 'Allergy' 'Hepatitis C'
#  'Impetigo' 'Migraine' 'Pneumonia' 'Hepatitis E' 'Chronic cholestasis'
#  'Hypothyroidism' 'Typhoid' 'Drug Reaction' 'Hypothyroidism'
#  'Peptic ulcer diseae' 'Hepatitis B' 'Heart attack' 'Hypoglycemia'
#  'Osteoarthristis' 'Allergy' 'Tuberculosis' 'Varicose veins' 'Hepatitis C'
#  'GERD' 'Dengue' 'Heart attack' 'Chronic cholestasis' 'Gastroenteritis'
#  'Fungal infection' 'Migraine' 'Impetigo' 'Chicken pox'
#  '(vertigo) Paroymsal  Positional Vertigo' 'hepatitis A' 'Hepatitis C'
#  'Varicose veins' 'Chronic cholestasis' 'hepatitis A' 'Migraine'
#  'Chicken pox' 'Hypoglycemia' 'hepatitis A' 'Impetigo' 'Hypertension '
#  'Bronchial Asthma' 'Hepatitis B' 'Diabetes ' 'Hyperthyroidism'
#  'Hepatitis B' 'GERD' 'Drug Reaction' 'Chronic cholestasis'
#  'Alcoholic hepatitis' '(vertigo) Paroymsal  Positional Vertigo'
#  'Hepatitis C' 'Alcoholic hepatitis' 'Pneumonia' 'Pneumonia'
#  'Heart attack' 'Dimorphic hemmorhoids(piles)' 'Hypoglycemia'
#  'Chronic cholestasis' 'Tuberculosis' 'Fungal infection' 'Typhoid'
#  'Gastroenteritis' 'Hepatitis E' 'Allergy' 'Dimorphic hemmorhoids(piles)'
#  'Pneumonia' 'Tuberculosis' 'Migraine' 'Hyperthyroidism' 'GERD'
#  'Tuberculosis' 'Gastroenteritis' 'Cervical spondylosis' 'Common Cold'
#  'Hypothyroidism' 'Cervical spondylosis' 'Hyperthyroidism' 'Impetigo'
#  'Acne' 'hepatitis A' 'Osteoarthristis' 'hepatitis A' 'Diabetes ' 'AIDS'
#  'Fungal infection' 'Typhoid' 'Chicken pox' 'Allergy'
#  'Dimorphic hemmorhoids(piles)' 'AIDS' 'Acne' 'Diabetes ' 'Allergy'
#  'Alcoholic hepatitis' 'Malaria' 'Malaria' 'Jaundice' 'Acne' 'Diabetes '
#  'Hypertension ' 'Urinary tract infection' 'Allergy' 'Bronchial Asthma'
#  'Alcoholic hepatitis' 'Migraine' 'Jaundice' 'Impetigo' 'Hypertension '
#  'Hyperthyroidism' 'Hypothyroidism' 'Hepatitis E' 'Arthritis'
#  'Hepatitis E' 'Common Cold' 'Jaundice' 'Varicose veins'
#  'Bronchial Asthma' 'Pneumonia' 'Hypothyroidism' 'Drug Reaction' 'Dengue'
#  'Impetigo' 'Chronic cholestasis' 'GERD' 'Chronic cholestasis' 'Arthritis'
#  'Acne' 'Hepatitis D' 'Peptic ulcer diseae' 'Hepatitis D' 'GERD'
#  'Urinary tract infection' 'Impetigo' 'Varicose veins' 'Hepatitis B'
#  'Dimorphic hemmorhoids(piles)' 'Allergy' 'Fungal infection' 'AIDS'
#  'Typhoid' 'Urinary tract infection' 'Gastroenteritis' 'Hepatitis E'
#  'Peptic ulcer diseae' 'Common Cold' 'Hypoglycemia'
#  'Urinary tract infection' 'Typhoid' 'Chronic cholestasis' 'Dengue'
#  'Psoriasis' 'Heart attack' 'AIDS' 'Dengue' 'Pneumonia' 'AIDS' 'Typhoid'
#  'Urinary tract infection' 'Impetigo' 'Drug Reaction'
#  'Paralysis (brain hemorrhage)' 'Dengue' 'Hypertension ' 'Migraine' 'Acne'
#  'Malaria' 'hepatitis A' 'Osteoarthristis' 'Psoriasis' 'Malaria'
#  'Arthritis' 'Pneumonia' 'Paralysis (brain hemorrhage)'
#  'Peptic ulcer diseae' 'Common Cold' 'Malaria' 'Common Cold' 'Common Cold'
#  'Arthritis' 'AIDS' 'Gastroenteritis' 'Diabetes ' 'Bronchial Asthma'
#  'Dimorphic hemmorhoids(piles)' 'Malaria' 'Alcoholic hepatitis' 'Jaundice'
#  'Dimorphic hemmorhoids(piles)' 'Gastroenteritis' 'Typhoid'
#  'Chronic cholestasis' 'Fungal infection' 'Acne' 'Typhoid'
#  'Hyperthyroidism' 'Typhoid' 'Urinary tract infection'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Impetigo' 'Fungal infection'
#  'Alcoholic hepatitis' 'Chronic cholestasis' 'Malaria' 'Hepatitis E'
#  'Bronchial Asthma' 'Arthritis' 'Pneumonia' 'Heart attack' 'hepatitis A'
#  'Diabetes ' 'Typhoid' 'Tuberculosis' 'Common Cold'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Hepatitis B' 'Tuberculosis'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Hypoglycemia' 'AIDS'
#  'hepatitis A' 'Peptic ulcer diseae' 'Psoriasis' 'Drug Reaction'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Typhoid' 'Hypertension '
#  'Drug Reaction' 'Dimorphic hemmorhoids(piles)' 'Bronchial Asthma'
#  'Arthritis' 'Gastroenteritis' 'Drug Reaction' 'Arthritis' 'AIDS'
#  'Jaundice' 'Paralysis (brain hemorrhage)' 'Fungal infection'
#  'Hypoglycemia' 'Hypertension ' 'Bronchial Asthma'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Malaria' 'Typhoid'
#  'Hypothyroidism' 'Typhoid' 'Malaria' 'Common Cold' 'Pneumonia'
#  'Hypoglycemia' 'Acne' 'Psoriasis' 'Migraine' 'Chicken pox'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Hyperthyroidism'
#  'Peptic ulcer diseae' 'Bronchial Asthma' 'Bronchial Asthma'
#  'Hypothyroidism' 'Heart attack' 'Hepatitis C' 'Acne' 'Varicose veins'
#  'Acne' 'Hepatitis D' 'Hepatitis D' 'Heart attack' 'Hepatitis C'
#  'Diabetes ' 'Bronchial Asthma' 'Bronchial Asthma' 'Cervical spondylosis'
#  'Gastroenteritis' 'Bronchial Asthma' 'Tuberculosis' 'Varicose veins'
#  'Hepatitis D' 'Jaundice' 'Tuberculosis' 'Alcoholic hepatitis'
#  'Hyperthyroidism' 'Hypertension ' 'Dimorphic hemmorhoids(piles)'
#  'Pneumonia' 'Chronic cholestasis' 'Drug Reaction' 'Peptic ulcer diseae'
#  'hepatitis A' 'Hypertension ' 'Urinary tract infection' 'Gastroenteritis'
#  'Allergy' 'Cervical spondylosis' 'Impetigo' 'AIDS' 'Alcoholic hepatitis'
#  'Dengue' 'Chronic cholestasis' 'Acne' 'Diabetes ' 'Varicose veins'
#  'Hepatitis D' 'Dimorphic hemmorhoids(piles)' 'Gastroenteritis'
#  'Hypothyroidism' 'Dimorphic hemmorhoids(piles)' 'Pneumonia'
#  'Hypothyroidism' 'Impetigo' 'GERD' 'Arthritis' 'Varicose veins'
#  'Impetigo' 'Hepatitis E' '(vertigo) Paroymsal  Positional Vertigo'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Arthritis' 'GERD'
#  'Hypothyroidism' 'Psoriasis' 'Bronchial Asthma' 'Acne' 'Drug Reaction'
#  'Fungal infection' 'Chicken pox' 'Hypoglycemia' 'Impetigo' 'Chicken pox'
#  'Hypertension ' 'Hepatitis B' 'Psoriasis' 'Migraine' 'Common Cold' 'AIDS'
#  'hepatitis A' 'Chronic cholestasis' 'Hypothyroidism' 'Heart attack'
#  'Hepatitis C' 'Acne' 'Typhoid' 'Hypoglycemia' 'Urinary tract infection'
#  'AIDS' 'Fungal infection' 'Acne' 'Common Cold' 'Cervical spondylosis'
#  'Tuberculosis' 'Hepatitis D' 'Hypertension ' 'hepatitis A'
#  'Peptic ulcer diseae' 'AIDS' 'Common Cold' 'Cervical spondylosis'
#  'Allergy' 'Allergy' 'Pneumonia' 'Acne' 'Dengue' 'Hepatitis C' 'Malaria'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Typhoid' 'hepatitis A'
#  'Tuberculosis' 'Hypoglycemia' 'Gastroenteritis' 'Allergy' 'Dengue'
#  'Hepatitis D' 'Varicose veins' 'Hepatitis E' 'Hepatitis E' 'Impetigo'
#  'Psoriasis' 'Osteoarthristis' 'Psoriasis' 'Hypoglycemia' 'Allergy'
#  'Jaundice' 'Hepatitis E' 'Hepatitis B' 'Hyperthyroidism' 'Acne'
#  'Pneumonia' 'Chronic cholestasis' 'Pneumonia' 'Allergy' 'AIDS'
#  'Chronic cholestasis' 'Heart attack'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Hepatitis D' 'Diabetes '
#  'Bronchial Asthma' 'Psoriasis' 'Heart attack'
#  'Dimorphic hemmorhoids(piles)' 'Heart attack'
#  'Dimorphic hemmorhoids(piles)' 'Hypoglycemia' 'Hepatitis E'
#  'Tuberculosis' 'Urinary tract infection'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Hepatitis E' 'Hypertension '
#  'Arthritis' '(vertigo) Paroymsal  Positional Vertigo' 'Acne'
#  'Hypoglycemia' 'Drug Reaction' 'Bronchial Asthma' 'Hypoglycemia'
#  'Common Cold' 'Tuberculosis' 'Bronchial Asthma' 'Chronic cholestasis'
#  'Psoriasis' 'Urinary tract infection' 'Migraine' 'Osteoarthristis'
#  'Drug Reaction' 'Diabetes ' 'Fungal infection' 'Heart attack'
#  'Tuberculosis' 'Urinary tract infection' 'Hepatitis D' 'Migraine'
#  'Hepatitis C' 'Hepatitis E' 'Drug Reaction' 'Hepatitis E'
#  'Dimorphic hemmorhoids(piles)' 'Osteoarthristis' 'Hypothyroidism'
#  'Impetigo' 'Acne' 'Migraine' 'Bronchial Asthma' 'Hepatitis E' 'GERD'
#  'Hyperthyroidism' 'Pneumonia' 'Drug Reaction' 'Cervical spondylosis'
#  'Psoriasis' 'Urinary tract infection' 'Tuberculosis' 'Heart attack'
#  'Gastroenteritis' 'Hypertension ' 'Chicken pox' 'hepatitis A'
#  'Osteoarthristis' 'Hypoglycemia' 'Jaundice' 'Impetigo' 'Hypothyroidism'
#  'Arthritis' 'Bronchial Asthma' 'Osteoarthristis' 'Hepatitis B'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Hypertension '
#  'Urinary tract infection' 'Peptic ulcer diseae' 'Peptic ulcer diseae'
#  'Hepatitis C' 'Hypothyroidism' 'Cervical spondylosis' 'Chicken pox'
#  'Common Cold' 'hepatitis A' 'Hepatitis E' 'Tuberculosis'
#  'Bronchial Asthma' 'Hypoglycemia' 'Urinary tract infection'
#  'Urinary tract infection' 'Migraine' 'Hepatitis B'
#  'Dimorphic hemmorhoids(piles)' 'Osteoarthristis' 'Peptic ulcer diseae'
#  'Hepatitis B' 'Common Cold' 'Gastroenteritis' 'Jaundice' 'Arthritis'
#  'Fungal infection' 'Urinary tract infection'
#  'Paralysis (brain hemorrhage)' 'Jaundice' 'Hypoglycemia'
#  'Peptic ulcer diseae' 'GERD' '(vertigo) Paroymsal  Positional Vertigo'
#  'GERD' 'Hepatitis D' 'hepatitis A' 'Migraine' 'Chronic cholestasis'
#  'Pneumonia' 'Hepatitis C' 'Common Cold' 'Peptic ulcer diseae' 'Pneumonia'
#  'Alcoholic hepatitis' 'Osteoarthristis' 'Gastroenteritis' 'GERD'
#  'Hepatitis C' 'Varicose veins' 'Chronic cholestasis'
#  'Dimorphic hemmorhoids(piles)' 'Chicken pox' 'Chronic cholestasis'
#  'Psoriasis' 'Impetigo' 'Hyperthyroidism' 'Psoriasis' 'GERD'
#  'Hyperthyroidism' '(vertigo) Paroymsal  Positional Vertigo'
#  'Peptic ulcer diseae' 'Bronchial Asthma' 'Dengue' 'hepatitis A'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Dimorphic hemmorhoids(piles)'
#  'Osteoarthristis' 'Psoriasis' 'Urinary tract infection' 'Malaria'
#  'Osteoarthristis' 'Hypoglycemia' 'Hypothyroidism' 'Acne' 'Hypoglycemia'
#  'Dimorphic hemmorhoids(piles)' 'Dimorphic hemmorhoids(piles)'
#  'Cervical spondylosis' 'Varicose veins' 'Urinary tract infection'
#  'Hypothyroidism' 'Fungal infection' 'AIDS' 'Cervical spondylosis'
#  'Pneumonia' 'Hyperthyroidism' 'Hypothyroidism'
#  'Dimorphic hemmorhoids(piles)' 'Varicose veins' 'Hypothyroidism'
#  'Varicose veins' 'Impetigo' 'Heart attack' 'Chronic cholestasis'
#  'Hypothyroidism' 'Acne' 'Hepatitis B' 'Fungal infection' 'Migraine'
#  'Varicose veins' 'Gastroenteritis' 'Heart attack' 'Dengue' 'Hepatitis E'
#  'Paralysis (brain hemorrhage)' 'Fungal infection' 'Chronic cholestasis'
#  'Cervical spondylosis' 'Gastroenteritis' 'Cervical spondylosis' 'AIDS'
#  'Migraine' 'Paralysis (brain hemorrhage)' 'Hypothyroidism' 'Typhoid'
#  'Hypoglycemia' 'Gastroenteritis' 'Psoriasis' 'Hepatitis B'
#  'Hyperthyroidism' 'Gastroenteritis' 'Malaria' 'Varicose veins' 'AIDS'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Dengue' 'Fungal infection'
#  'Psoriasis' 'Hepatitis C' 'GERD' 'Acne' 'Hypertension ' 'Migraine'
#  'Common Cold' 'Hypothyroidism' 'Peptic ulcer diseae' 'Osteoarthristis'
#  'Jaundice' 'Chronic cholestasis' 'Migraine' 'Psoriasis' 'Hepatitis E'
#  'Impetigo' 'Hypoglycemia' 'Paralysis (brain hemorrhage)' 'GERD' 'GERD'
#  'Gastroenteritis' 'Hypertension ' 'Hepatitis E' 'Hepatitis D'
#  'Hepatitis D' 'Varicose veins' 'Allergy' 'Acne' 'Heart attack'
#  'Peptic ulcer diseae' 'Diabetes ' 'Chicken pox' 'Hypothyroidism'
#  'Hepatitis C' 'Migraine' 'Acne' 'Diabetes ' 'Typhoid' 'Hypoglycemia'
#  'Dengue' 'Common Cold' 'Pneumonia' 'Jaundice' 'hepatitis A' 'Typhoid'
#  'Hepatitis D' 'Urinary tract infection' 'Acne'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Jaundice'
#  'Chronic cholestasis' 'Chicken pox' 'Dimorphic hemmorhoids(piles)'
#  'Dimorphic hemmorhoids(piles)' 'Jaundice' 'AIDS' 'Osteoarthristis'
#  'Hypertension ' 'Heart attack' 'Arthritis' 'Urinary tract infection'
#  'Chicken pox' 'Chronic cholestasis' 'Heart attack' 'Hyperthyroidism'
#  '(vertigo) Paroymsal  Positional Vertigo'
#  '(vertigo) Paroymsal  Positional Vertigo' 'GERD'
#  '(vertigo) Paroymsal  Positional Vertigo' 'Fungal infection' 'Diabetes '
#  'Impetigo' 'Cervical spondylosis' 'Dengue' 'Hypothyroidism' 'Common Cold'
#  'hepatitis A' 'Typhoid' 'Hypertension ' 'Pneumonia' 'Hyperthyroidism'
#  'Chronic cholestasis' 'Jaundice' 'Heart attack' 'Fungal infection'
#  'Alcoholic hepatitis' 'Chronic cholestasis' 'Hepatitis C' 'Hepatitis D'
#  'Common Cold' 'Urinary tract infection' 'Osteoarthristis'
#  'Hypothyroidism' 'Chronic cholestasis' 'Migraine' 'Hepatitis E'
#  'Diabetes ' 'Hepatitis C' 'Fungal infection' 'Impetigo']
#
# Validation Accuracy:  1.0
#
# Validation Confusion Matrix:
#  [[31  0  0 ...  0  0  0]
#  [ 0 23  0 ...  0  0  0]
#  [ 0  0 34 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 27  0  0]
#  [ 0  0  0 ...  0 25  0]
#  [ 0  0  0 ...  0  0 26]]
#
# Cross Validation Score:
#  [0.93597561 0.9054878  0.89939024]
#
# Classification Report:
#                                           precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00        31
#                                    AIDS       1.00      1.00      1.00        23
#                                    Acne       1.00      1.00      1.00        34
#                     Alcoholic hepatitis       1.00      1.00      1.00        19
#                                 Allergy       1.00      1.00      1.00        21
#                               Arthritis       1.00      1.00      1.00        21
#                        Bronchial Asthma       1.00      1.00      1.00        31
#                    Cervical spondylosis       1.00      1.00      1.00        22
#                             Chicken pox       1.00      1.00      1.00        21
#                     Chronic cholestasis       1.00      1.00      1.00        31
#                             Common Cold       1.00      1.00      1.00        26
#                                  Dengue       1.00      1.00      1.00        19
#                               Diabetes        1.00      1.00      1.00        21
#            Dimorphic hemmorhoids(piles)       1.00      1.00      1.00        24
#                           Drug Reaction       1.00      1.00      1.00        19
#                        Fungal infection       1.00      1.00      1.00        24
#                                    GERD       1.00      1.00      1.00        25
#                         Gastroenteritis       1.00      1.00      1.00        27
#                            Heart attack       1.00      1.00      1.00        28
#                             Hepatitis B       1.00      1.00      1.00        20
#                             Hepatitis C       1.00      1.00      1.00        19
#                             Hepatitis D       1.00      1.00      1.00        23
#                             Hepatitis E       1.00      1.00      1.00        27
#                           Hypertension        1.00      1.00      1.00        20
#                         Hyperthyroidism       1.00      1.00      1.00        18
#                            Hypoglycemia       1.00      1.00      1.00        27
#                          Hypothyroidism       1.00      1.00      1.00        31
#                                Impetigo       1.00      1.00      1.00        34
#                                Jaundice       1.00      1.00      1.00        19
#                                 Malaria       1.00      1.00      1.00        19
#                                Migraine       1.00      1.00      1.00        21
#                         Osteoarthristis       1.00      1.00      1.00        21
#            Paralysis (brain hemorrhage)       1.00      1.00      1.00        17
#                     Peptic ulcer diseae       1.00      1.00      1.00        25
#                               Pneumonia       1.00      1.00      1.00        26
#                               Psoriasis       1.00      1.00      1.00        22
#                            Tuberculosis       1.00      1.00      1.00        22
#                                 Typhoid       1.00      1.00      1.00        28
#                 Urinary tract infection       1.00      1.00      1.00        27
#                          Varicose veins       1.00      1.00      1.00        25
#                             hepatitis A       1.00      1.00      1.00        26
#
#                                accuracy                           1.00       984
#                               macro avg       1.00      1.00      1.00       984
#                            weighted avg       1.00      1.00      1.00       984

# %%
test_acc
# Out:
# 0.9761904761904762

# %%
test_=pd.read_csv(r"C:\Users\dell\Desktop\projects\Phillps_hac\Disease-Prediction-from-Symptoms-master\dataset\test_data.csv")

# %%
#To find the predicted diseases from the test dataset : 
for i in range(test_.shape[0]):
    print("The symptoms are as follows ",end=':')
    for j in range(test_.shape[1]):
        if(test_.iloc[i][j]==1):
            print(test_.columns[j],end=" ,")
    print("")        
    print("The predicted disease is :", result[i])        
    print("\n")
# Out:
# The symptoms are as follows :itching ,skin_rash ,nodal_skin_eruptions ,dischromic _patches ,
# The predicted disease is : Fungal infection
#
#
# The symptoms are as follows :continuous_sneezing ,shivering ,chills ,watering_from_eyes ,
# The predicted disease is : Allergy
#
#
# The symptoms are as follows :stomach_pain ,acidity ,ulcers_on_tongue ,vomiting ,cough ,chest_pain ,
# The predicted disease is : GERD
#
#
# The symptoms are as follows :itching ,vomiting ,yellowish_skin ,nausea ,loss_of_appetite ,abdominal_pain ,yellowing_of_eyes ,
# The predicted disease is : Chronic cholestasis
#
#
# The symptoms are as follows :itching ,skin_rash ,stomach_pain ,burning_micturition ,spotting_ urination ,
# The predicted disease is : Drug Reaction
#
#
# The symptoms are as follows :vomiting ,indigestion ,loss_of_appetite ,abdominal_pain ,passage_of_gases ,internal_itching ,
# The predicted disease is : Peptic ulcer diseae
#
#
# The symptoms are as follows :muscle_wasting ,patches_in_throat ,high_fever ,extra_marital_contacts ,
# The predicted disease is : AIDS
#
#
# The symptoms are as follows :fatigue ,weight_loss ,restlessness ,lethargy ,irregular_sugar_level ,blurred_and_distorted_vision ,obesity ,excessive_hunger ,increased_appetite ,polyuria ,
# The predicted disease is : Diabetes
#
#
# The symptoms are as follows :vomiting ,sunken_eyes ,dehydration ,diarrhoea ,
# The predicted disease is : Gastroenteritis
#
#
# The symptoms are as follows :fatigue ,cough ,high_fever ,breathlessness ,family_history ,mucoid_sputum ,
# The predicted disease is : Bronchial Asthma
#
#
# The symptoms are as follows :headache ,chest_pain ,dizziness ,loss_of_balance ,lack_of_concentration ,
# The predicted disease is : Hypertension
#
#
# The symptoms are as follows :acidity ,indigestion ,headache ,blurred_and_distorted_vision ,excessive_hunger ,stiff_neck ,depression ,irritability ,visual_disturbances ,
# The predicted disease is : Migraine
#
#
# The symptoms are as follows :back_pain ,weakness_in_limbs ,neck_pain ,dizziness ,loss_of_balance ,
# The predicted disease is : Cervical spondylosis
#
#
# The symptoms are as follows :vomiting ,headache ,weakness_of_one_body_side ,altered_sensorium ,
# The predicted disease is : Paralysis (brain hemorrhage)
#
#
# The symptoms are as follows :itching ,vomiting ,fatigue ,weight_loss ,high_fever ,yellowish_skin ,dark_urine ,abdominal_pain ,
# The predicted disease is : Jaundice
#
#
# The symptoms are as follows :chills ,vomiting ,high_fever ,sweating ,headache ,nausea ,diarrhoea ,muscle_pain ,
# The predicted disease is : Malaria
#
#
# The symptoms are as follows :itching ,skin_rash ,fatigue ,lethargy ,high_fever ,headache ,loss_of_appetite ,mild_fever ,swelled_lymph_nodes ,malaise ,red_spots_over_body ,
# The predicted disease is : Chicken pox
#
#
# The symptoms are as follows :skin_rash ,chills ,joint_pain ,vomiting ,fatigue ,high_fever ,headache ,nausea ,loss_of_appetite ,pain_behind_the_eyes ,back_pain ,malaise ,muscle_pain ,red_spots_over_body ,
# The predicted disease is : Dengue
#
#
# The symptoms are as follows :chills ,vomiting ,fatigue ,high_fever ,headache ,nausea ,constipation ,abdominal_pain ,diarrhoea ,toxic_look_(typhos) ,belly_pain ,
# The predicted disease is : Typhoid
#
#
# The symptoms are as follows :joint_pain ,vomiting ,yellowish_skin ,dark_urine ,nausea ,loss_of_appetite ,abdominal_pain ,diarrhoea ,mild_fever ,yellowing_of_eyes ,muscle_pain ,
# The predicted disease is : hepatitis A
#
#
# The symptoms are as follows :itching ,fatigue ,lethargy ,yellowish_skin ,dark_urine ,loss_of_appetite ,abdominal_pain ,yellow_urine ,yellowing_of_eyes ,malaise ,receiving_blood_transfusion ,receiving_unsterile_injections ,
# The predicted disease is : Hepatitis B
#
#
# The symptoms are as follows :fatigue ,yellowish_skin ,nausea ,loss_of_appetite ,yellowing_of_eyes ,family_history ,
# The predicted disease is : Hepatitis C
#
#
# The symptoms are as follows :joint_pain ,vomiting ,fatigue ,yellowish_skin ,dark_urine ,nausea ,loss_of_appetite ,abdominal_pain ,yellowing_of_eyes ,
# The predicted disease is : Hepatitis D
#
#
# The symptoms are as follows :joint_pain ,vomiting ,fatigue ,high_fever ,yellowish_skin ,dark_urine ,nausea ,loss_of_appetite ,abdominal_pain ,yellowing_of_eyes ,acute_liver_failure ,coma ,stomach_bleeding ,
# The predicted disease is : Hepatitis E
#
#
# The symptoms are as follows :vomiting ,yellowish_skin ,abdominal_pain ,swelling_of_stomach ,distention_of_abdomen ,history_of_alcohol_consumption ,fluid_overload.1 ,
# The predicted disease is : Alcoholic hepatitis
#
#
# The symptoms are as follows :chills ,vomiting ,fatigue ,weight_loss ,cough ,high_fever ,breathlessness ,sweating ,loss_of_appetite ,mild_fever ,yellowing_of_eyes ,swelled_lymph_nodes ,malaise ,phlegm ,chest_pain ,blood_in_sputum ,
# The predicted disease is : Tuberculosis
#
#
# The symptoms are as follows :continuous_sneezing ,chills ,fatigue ,cough ,high_fever ,headache ,swelled_lymph_nodes ,malaise ,phlegm ,throat_irritation ,redness_of_eyes ,sinus_pressure ,runny_nose ,congestion ,chest_pain ,loss_of_smell ,muscle_pain ,
# The predicted disease is : Common Cold
#
#
# The symptoms are as follows :chills ,fatigue ,cough ,high_fever ,breathlessness ,sweating ,malaise ,phlegm ,chest_pain ,fast_heart_rate ,rusty_sputum ,
# The predicted disease is : Pneumonia
#
#
# The symptoms are as follows :constipation ,pain_during_bowel_movements ,pain_in_anal_region ,bloody_stool ,irritation_in_anus ,
# The predicted disease is : Dimorphic hemmorhoids(piles)
#
#
# The symptoms are as follows :vomiting ,breathlessness ,sweating ,chest_pain ,
# The predicted disease is : Heart attack
#
#
# The symptoms are as follows :fatigue ,cramps ,bruising ,obesity ,swollen_legs ,swollen_blood_vessels ,prominent_veins_on_calf ,
# The predicted disease is : Varicose veins
#
#
# The symptoms are as follows :fatigue ,weight_gain ,cold_hands_and_feets ,mood_swings ,lethargy ,dizziness ,puffy_face_and_eyes ,enlarged_thyroid ,brittle_nails ,swollen_extremeties ,depression ,irritability ,abnormal_menstruation ,
# The predicted disease is : Hypothyroidism
#
#
# The symptoms are as follows :fatigue ,mood_swings ,weight_loss ,restlessness ,sweating ,diarrhoea ,fast_heart_rate ,excessive_hunger ,muscle_weakness ,irritability ,abnormal_menstruation ,
# The predicted disease is : Hyperthyroidism
#
#
# The symptoms are as follows :vomiting ,fatigue ,anxiety ,sweating ,headache ,nausea ,blurred_and_distorted_vision ,excessive_hunger ,drying_and_tingling_lips ,slurred_speech ,irritability ,palpitations ,
# The predicted disease is : Hypoglycemia
#
#
# The symptoms are as follows :joint_pain ,neck_pain ,knee_pain ,hip_joint_pain ,swelling_joints ,painful_walking ,
# The predicted disease is : Osteoarthristis
#
#
# The symptoms are as follows :muscle_weakness ,stiff_neck ,swelling_joints ,movement_stiffness ,painful_walking ,
# The predicted disease is : Arthritis
#
#
# The symptoms are as follows :vomiting ,headache ,nausea ,spinning_movements ,loss_of_balance ,unsteadiness ,
# The predicted disease is : (vertigo) Paroymsal  Positional Vertigo
#
#
# The symptoms are as follows :skin_rash ,pus_filled_pimples ,blackheads ,scurring ,
# The predicted disease is : Acne
#
#
# The symptoms are as follows :burning_micturition ,bladder_discomfort ,foul_smell_of urine ,continuous_feel_of_urine ,
# The predicted disease is : Urinary tract infection
#
#
# The symptoms are as follows :skin_rash ,joint_pain ,skin_peeling ,silver_like_dusting ,small_dents_in_nails ,inflammatory_nails ,
# The predicted disease is : Psoriasis
#
#
# The symptoms are as follows :skin_rash ,high_fever ,blister ,red_sore_around_nose ,yellow_crust_ooze ,
# The predicted disease is : Impetigo
#
#
# The symptoms are as follows :itching ,skin_rash ,red_spots_over_body ,family_history ,skin_peeling ,red_sore_around_nose ,
# The predicted disease is : Drug Reaction
